# %% [markdown]
# <a href="https://colab.research.google.com/github/daran10/Estudo-Data-Science/blob/main/Imers%C3%A3o_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=True'
df = pd.read_csv(url_dados, compression = 'zip')

# %%
df.shape
# Out:
# (23814, 877)

# %%
df.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
df.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
df['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
df['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
df['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
df['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
df['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
df.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
df['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
df['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
df['tratamento'].value_counts().plot.pie()

# %%
df['dose'].value_counts().plot.pie()

# %%
df['tempo'].value_counts().plot.pie()

# %%
df['tempo'].value_counts().plot.bar()

# %%
mapa = {'droga':'composto'}
df.rename(columns=mapa, inplace = True)

# %%
df.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = df['composto'].value_counts().index[0:5]

# %%
df.query('composto in @cod_compostos ')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
sns.set()
plt.figure(figsize = (8,6))
ax = sns.countplot(x='composto', data = df.query('composto in @cod_compostos ').sort_values('composto', ascending = False))
# set labels
plt.xlabel("Composto", size=15)
plt.ylabel("Contagem", size=15)
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(df['g-0'].unique())
# Out:
# 14367

# %%
df['g-0'].max()
# Out:
# 10.0

# %%
df['g-0'].min()
# Out:
# -5.513

# %%
df['g-0'].hist(bins = 100)

# %%
df.loc[:,'g-0': 'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
df.loc[:,'g-0': 'g-771'].describe().T['mean'].hist(bins= 30)

# %%
df.loc[:,'g-0': 'g-771'].describe().T['min'].hist(bins= 30)

# %%
df.loc[:,'g-0': 'g-771'].describe().T['max'].hist(bins= 30)

# %%
df.loc[:,'c-0': 'c-99'].describe().T['mean'].hist(bins= 30)

# %%
sns.boxplot(x= 'g-0', data=df)

# %%
plt.figure(figsize = (10,6))
sns.boxplot(x= 'tratamento', y= 'g-0', data=df)
plt.show()

# %% [markdown]
# ### Crosstab

# %%
pd.crosstab(df['dose'], df['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
#multi index
pd.crosstab([df['dose'], df['tempo']], df['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
#propocionalidade do df
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
#propocionalidade na linha
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], normalize ='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
new_df = df[['g-0', 'g-3', 'tratamento', 'tempo']]

# %%
new_df
# Out:
#           g-0     g-3    tratamento  tempo
# 0      1.0620 -0.6208     com_droga     24
# 1      0.0743  0.0604     com_droga     72
# 2      0.6280 -0.0764     com_droga     48
# 3     -0.5138  0.5288     com_droga     48
# 4     -0.3254  0.6919     com_droga     72
# ...       ...     ...           ...    ...
# 23809  0.1394 -0.5080     com_droga     24
# 23810 -1.3260  0.9905     com_droga     24
# 23811  0.3942 -0.7389  com_controle     48
# 23812  0.6660  0.2044     com_droga     24
# 23813 -0.8598  0.7952     com_droga     72
#
# [23814 rows x 4 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=new_df)

# %%
sns.lmplot(x='g-0', y='g-3', data=new_df, line_kws={'color': 'red'})

# %%
sns.lmplot(x='g-0', y='g-3', data=new_df, line_kws={'color': 'red'},col='tratamento', row='tempo')

# %%
df.loc[:, 'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = df.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Aula 4

# %%
df2 = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=True')

# %%
df2.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
contagem_moa = df2.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
df2.shape
# Out:
# (23814, 207)

# %%
df2.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
df2['n_moa']=df2.select_dtypes('int64').sum(axis = 1)

# %%
df2['ativo_moa']=(df2['n_moa']!= 0)

# %%
df2.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
df3 = pd.merge(df, df2[['id','n_moa', 'ativo_moa']], on= 'id')

# %%
df3.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
df3.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
df3.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = df3['composto'].value_counts().index[:5]
plt.figure(figsize=(10,8))
sns.boxplot(data=df3.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# Usando Machine Learning para classicaçao

# %%
from sklearn.linear_model import LogisticRegression as lr
from sklearn.model_selection import train_test_split

# %%
modelo_rlogistica = lr()
x=df3.select_dtypes('float64')
y=df3['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y, test_size = 0.2)

modelo_rlogistica = lr(max_iter=1000)
modelo_rlogistica.fit(x_treino,y_treino)
modelo_rlogistica.score(x_teste,y_teste)
# Out:
# 0.6334243124081461

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

# %%
modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6055007348309889

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
x=df3.select_dtypes('float64')
y=df3['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y, test_size = 0.2)

modelo_arvore = DecisionTreeClassifier(max_depth=3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6145286584085661

# %%
fig, ax = plt.subplots(figsize = (15,10), facecolor='k')
tree.plot_tree(
    modelo_arvore,
    ax=ax,
    fontsize=10,
    rounded = True,
    filled = True,
    feature_names=x_treino.columns,
    class_names = ['Não Ativado', 'Ativado'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
x=df3.select_dtypes('float64')
y=df3['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y,stratify = y, random_state = 376, test_size = 0.2)

teste = []
treino = []
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth=i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6210371614528658,
#  0.6189376443418014,
#  0.6204073063195465,
#  0.6206172580306529,
#  0.6159983203863112,
#  0.6145286584085661,
#  0.6105395758975436,
#  0.5966827629645182,
#  0.5985723283644762,
#  0.5981524249422633]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.6895176106241142,
#  0.706892026665267,
#  0.7294105296309905,
#  0.7528738648889822,
#  0.776809616293108,
#  0.7991181565272164]

# %%
sns.lineplot(x = range(1,15), y = teste, label = 'teste')
sns.lineplot(x = range(1,15), y = treino, label = 'treino')
